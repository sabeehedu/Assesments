# %%
num =int(input("enter 3 digits number"))
total=0
numstr=str(num)
print(numstr)
for digit in numstr:
    total=total+ int(digit)
print(f"total is {total}")
# Out:
# enter 3 digits number 123
# 123
# 3
# total is 6
