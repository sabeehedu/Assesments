# %%
name=input("enter your name")
print(f"Hello, {name}! Welcome to the Python assignment.")
print(name.upper())
print(name.lower())
print(len(name))
print(name.replace(" ","-"))

birthYear=int(input("enter your birth year"))
print(birthYear)
aproxage=2026-birthYear
print(f'your age is {aproxage}')
fruits=input("enter three fruites separate by comma")
fruits[0]
fruitslist=fruits.split(",")
# Out:
# enter three fruites separate by comma grames,melon,banana

# %%
print(fruitslist)
# Out:
# ['grames', 'melon', 'banana']

# %%
fruitslist[0]
# Out:
# 'grames'

# %%
fruitslist[2]
# Out:
# 'banana'

# %%
fruitslist[1]
# Out:
# 'melon'

# %%
fruitslist[0:2]
# Out:
# ['grames', 'melon']

# %%
fruitslist.append("guava")

# %%
fruitslist
# Out:
# ['grames', 'melon', 'banana', 'guava']

# %%
fruitslist.pop()
# Out:
# 'guava'

# %%
print(fruitslist)
# Out:
# ['grames', 'melon', 'banana']

# %%
len(fruitslist)
# Out:
# 3
