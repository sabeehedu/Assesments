# %%
print("Hello, everyone! I am learning Python. 😄")
# Out:
# Hello, everyone! I am learning Python. 😄

# %%
name="sabeeh"
age=26
animal="lion"

print("name:",name)
print("age:",age)
print("animal:",animal)
# Out:
# name: sabeeh
# age: 26
# animal: lion

# %%
name="sabeeh"
age=26
animal="lion"

print(f"my name is {name} and my age is {age} , and my animal is {animal}")
# Out:
# my name is sabeeh and my age is 26 , and my animal is lion

# %%
movie="Mission Impossible"
birthyear=1999
snack=5.9
print(movie)
print(birthyear)
print(snack)
# Out:
# Mission Impossible
# 1999
# 5.9

# %%
hobby="Watching Movies"

print(f"My favorite hobby is {hobby}")
# Out:
# My favorite hobby is Watching Movies
